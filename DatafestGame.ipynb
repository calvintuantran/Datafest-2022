# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
edit_database = pd.read_csv("use.csv", low_memory=False)
edit_database
# Out:
#           IDs  total_time  idle_times  engaged_time  max_progression  age  \
# 0     6427001       37718        3369         34349             1.00   13
# 1     6427002        3735           0          3735             0.04   13
# 2     6427004       30307        1651         28656             1.00   13
# 3     6427005        3729           0          3729             0.00   13
# 4     6427006       31927        1856         30071             1.00   13
# ..        ...         ...         ...           ...              ...  ...
# 161   6626006       40352        2255         38097             0.12   13
# 162   6626007      467294      434789         32505             0.32   11
# 163   7540835         535           0           535             0.00   14
# 164  65670031       11100           0         11100             1.00   12
# 165  65670032        5767           0          5767             0.36   12
#
#      gender         ethnicity  School
# 0      Male          Hispanic    3561
# ...

# %%
import seaborn as sns
sns.set_theme()

# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=edit_database,
    x="age", y="max_progression", hue="School",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("age", "max_progression")

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="age", y="max_progression", col="ethnicity", hue="ethnicity", data=edit_database,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...
